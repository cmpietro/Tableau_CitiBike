# %%
#Import Dependencies

import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Import Data
file1 = "All CitiBike Data/201803-citibike-tripdata.csv"


marchCB = pd.read_csv(file1)

# %%
marchCB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976672 entries, 0 to 976671
# Data columns (total 15 columns):
# tripduration               976672 non-null int64
# starttime                  976672 non-null object
# stoptime                   976672 non-null object
# start station id           976672 non-null int64
# start station name         976672 non-null object
# start station latitude     976672 non-null float64
# start station longitude    976672 non-null float64
# end station id             976672 non-null int64
# end station name           976672 non-null object
# end station latitude       976672 non-null float64
# end station longitude      976672 non-null float64
# bikeid                     976672 non-null int64
# usertype                   976672 non-null object
# birth year                 976672 non-null int64
# gender                     976672 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 111.8+ MB

# %%
marchCB.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  9.766720e+05     976672.000000           976672.000000
# mean   8.819937e+02       1498.556608               40.737436
# std    2.743450e+04       1412.410357                0.033025
# min    6.100000e+01         72.000000               40.646538
# 25%    3.240000e+02        377.000000               40.718939
# 50%    5.330000e+02        498.000000               40.739126
# 75%    9.040000e+02       3177.000000               40.756687
# max    1.502093e+07       3674.000000               45.506264
#
#        start station longitude  end station id  end station latitude  \
# count            976672.000000   976672.000000         976672.000000
# mean                -73.982980     1488.513184             40.737107
# std                   0.018135     1410.161032              0.032750
# min                 -74.017134       72.000000             40.646538
# ...

# %%
# find rows / trip number
marchCB.shape
# Out:
# (976672, 15)

# %%
marchCB.gender.value_counts(dropna=False)
# Out:
# 1    702533
# 2    212687
# 0     61452
# Name: gender, dtype: int64

# %%
marchCB.usertype.value_counts(dropna=False)
# Out:
# Subscriber    917637
# Customer       59035
# Name: usertype, dtype: int64

# %%
marchCB.bikeid.value_counts(dropna=False)
# Out:
# 33121    251
# 29964    236
# 31851    232
# 32005    231
# 30698    231
# 32358    228
# 30841    226
# 30565    224
# 32001    224
# 33102    221
# 31341    220
# 30729    219
# 29985    219
# 30707    219
# 32400    218
# 32003    218
# 32692    218
# 30216    218
# 32345    218
# 32309    217
# 31264    217
# 33028    217
# 33110    216
# 31249    216
# 30387    216
# 31262    215
# 32716    215
# 33048    214
# 30200    214
# 32534    214
#         ...
# 27804      1
# 25814      1
# 27862      1
# 29364      1
# 27140      1
# 29169      1
# 26799      1
# 18703      1
# 22489      1
# 20094      1
# 33548      1
# 28469      1
# 27109      1
# 25224      1
# 20871      1
# 15923      1
# 25657      1
# 25377      1
# 17661      1
# 26737      1
# 16333      1
# 26121      1
# 28354      1
# 25747      1
# 16548      1
# 28610      1
# 26819      1
# 14646      1
# 25053      1
# 30270      1
# Name: bikeid, Length: 10935, dtype: int64

# %%
marchCB.min()
# Out:
# tripduration                                     61
# starttime                  2018-03-01 00:00:03.4060
# stoptime                   2018-03-01 00:01:36.5460
# start station id                                 72
# start station name                 1 Ave & E 110 St
# start station latitude                      40.6465
# start station longitude                    -74.0171
# end station id                                   72
# end station name                   1 Ave & E 110 St
# end station latitude                        40.6465
# end station longitude                      -74.0557
# bikeid                                        14529
# usertype                                   Customer
# birth year                                     1885
# gender                                            0
# dtype: object

# %%
marchCB.max()
# Out:
# tripduration                                   15020934
# starttime                      2018-03-31 23:59:58.1720
# stoptime                       2018-09-05 14:50:33.4160
# start station id                                   3674
# start station name         Wythe Ave & Metropolitan Ave
# start station latitude                          45.5063
# start station longitude                        -73.5689
# end station id                                     3674
# end station name           Wythe Ave & Metropolitan Ave
# end station latitude                            45.5063
# end station longitude                          -73.5689
# bikeid                                            33551
# usertype                                     Subscriber
# birth year                                         2002
# gender                                                2
# dtype: object

# %%
marchCB['birth year'].min()
# Out:
# 1885

# %%
marchCB['tripduration'].median()
# Out:
# 533.0

# %%
marchCB['birth year'].head()
# Out:
# 0    1973
# 1    1965
# 2    1984
# 3    1981
# 4    1990
# Name: birth year, dtype: int64

# %%
# birth year small problem or large
birthyearsort = marchCB.sort_values('birth year', ascending = True)
birthyearsort.head(100)
# Out:
#         tripduration                 starttime                  stoptime  \
# 483618           996  2018-03-24 10:13:18.1590  2018-03-24 10:29:54.9970
# 432712          1019  2018-03-15 18:29:05.1340  2018-03-15 18:46:04.2670
# 374022          1132  2018-03-31 12:24:07.7260  2018-03-31 12:43:00.4190
# 545590           390  2018-03-25 12:34:11.6550  2018-03-25 12:40:42.1120
# 373629           496  2018-03-26 07:39:33.4000  2018-03-26 07:47:49.6800
# 900180           647  2018-03-06 14:58:32.3440  2018-03-06 15:09:20.1680
# 534010          1013  2018-03-31 08:50:51.9670  2018-03-31 09:07:45.3940
# 391240           388  2018-03-24 09:47:28.8300  2018-03-24 09:53:57.3370
# 373602           692  2018-03-25 09:45:30.3630  2018-03-25 09:57:02.7750
# 373200           781  2018-03-18 09:37:22.2520  2018-03-18 09:50:24.1670
# 545984           826  2018-03-30 10:22:59.4680  2018-03-30 10:36:46.0820
# 526924           553  2018-03-04 10:31:24.8680  2018-03-04 10:40:38.2500
# ...

# %%
# isolate those rows whose birth year is older than 100 yo

marchCB.loc[marchCB['birth year'] < 1919]
# Out:
#         tripduration                 starttime                  stoptime  \
# 384              621  2018-03-08 17:50:27.0870  2018-03-08 18:00:48.5680
# 602              843  2018-03-10 17:03:41.8170  2018-03-10 17:17:45.7730
# 15971            395  2018-03-04 22:20:31.5840  2018-03-04 22:27:07.2020
# 16077            243  2018-03-06 16:56:18.1750  2018-03-06 17:00:22.1710
# 16620            606  2018-03-16 17:19:15.8370  2018-03-16 17:29:22.3130
# 16629            147  2018-03-16 20:33:26.2190  2018-03-16 20:35:54.0320
# 18755            696  2018-03-12 15:06:00.2630  2018-03-12 15:17:36.2630
# 19544            284  2018-03-18 22:35:10.3400  2018-03-18 22:39:55.2740
# 20352            410  2018-03-25 18:56:49.4270  2018-03-25 19:03:40.4050
# 21012            568  2018-03-29 23:22:55.7670  2018-03-29 23:32:24.0490
# 21163            297  2018-03-30 22:20:45.5660  2018-03-30 22:25:42.6190
# 23610            985  2018-03-01 16:10:54.2150  2018-03-01 16:27:19.7030
# ...

# %%
# remove 789 rows of data for all people older than 100

marchBY = marchCB.drop(marchCB[marchCB['birth year'] < 1919].index)

marchBY['birth year'].min()
# Out:
# 1919

# %%
marchBY.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  9.758830e+05     975883.000000           975883.000000
# mean   8.822765e+02       1498.289820               40.737433
# std    2.744558e+04       1412.383413                0.033029
# min    6.100000e+01         72.000000               40.646538
# 25%    3.240000e+02        376.000000               40.718822
# 50%    5.330000e+02        498.000000               40.739126
# 75%    9.045000e+02       3177.000000               40.756687
# max    1.502093e+07       3674.000000               45.506264
#
#        start station longitude  end station id  end station latitude  \
# count            975883.000000   975883.000000         975883.000000
# mean                -73.982981     1488.389074             40.737106
# std                   0.018135     1410.163568              0.032753
# min                 -74.017134       72.000000             40.646538
# ...

# %%
marchBY['tripduration'].max()
# Out:
# 15020934

# %%
# isolating trips greater than 4 hours. 

marchBY.loc[marchBY['tripduration'] > 15000]
# Out:
#         tripduration                 starttime                  stoptime  \
# 3061           38798  2018-03-22 21:29:37.1180  2018-03-23 08:16:15.6250
# 3420           27118  2018-03-29 08:26:58.9550  2018-03-29 15:58:57.8010
# 3425           16073  2018-03-29 08:43:24.5740  2018-03-29 13:11:18.4800
# 4483          329699  2018-03-11 17:57:21.3400  2018-03-15 13:32:20.7870
# 4711           40810  2018-03-18 21:20:47.0320  2018-03-19 08:40:57.4830
# 6824           15298  2018-03-11 13:09:02.7310  2018-03-11 17:24:01.1550
# 7006           52545  2018-03-12 20:06:45.2950  2018-03-13 10:42:30.6780
# 8036           16685  2018-03-23 10:12:41.1770  2018-03-23 14:50:46.3510
# 10156         178374  2018-03-11 12:39:18.7060  2018-03-13 14:12:12.7320
# 13305          58724  2018-03-15 18:26:57.9790  2018-03-16 10:45:42.0580
# 13496          15882  2018-03-19 18:27:45.9360  2018-03-19 22:52:28.6360
# 13911          95862  2018-03-29 17:23:50.1000  2018-03-30 20:01:32.7620
# ...

# %%
# remove 806 rows of data for trips greater than four hours. 
marchClean = marchBY.drop(marchBY[marchBY['tripduration'] > 15000].index)

marchClean['tripduration'].max()
# Out:
# 14995

# %%
marchClean.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count  975077.000000     975077.000000           975077.000000
# mean      715.174995       1497.810192               40.737435
# std       659.101539       1412.245027                0.033023
# min        61.000000         72.000000               40.646538
# 25%       324.000000        376.000000               40.718939
# 50%       533.000000        498.000000               40.739126
# 75%       903.000000       3177.000000               40.756687
# max     14995.000000       3674.000000               45.506264
#
#        start station longitude  end station id  end station latitude  \
# count            975077.000000   975077.000000         975077.000000
# mean                -73.982986     1487.855574             40.737109
# std                   0.018131     1410.017987              0.032746
# min                 -74.017134       72.000000             40.646538
# ...

# %%
marchClean['stoptime'].min()
# Out:
# '2018-03-01 00:01:36.5460'

# %%
marchClean['stoptime'].max()
# Out:
# '2018-04-01 02:25:27.3000'

# %%
marchClean['starttime'].min()
# Out:
# '2018-03-01 00:00:03.4060'

# %%
marchClean['starttime'].max()
# Out:
# '2018-03-31 23:59:58.1720'

# %%
marchClean['starttime'] = pd.to_datetime(marchClean.starttime)
marchClean.info('starttime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975077 entries, 0 to 976671
# Data columns (total 15 columns):
# tripduration               975077 non-null int64
# starttime                  975077 non-null datetime64[ns]
# stoptime                   975077 non-null object
# start station id           975077 non-null int64
# start station name         975077 non-null object
# start station latitude     975077 non-null float64
# start station longitude    975077 non-null float64
# end station id             975077 non-null int64
# end station name           975077 non-null object
# end station latitude       975077 non-null float64
# end station longitude      975077 non-null float64
# bikeid                     975077 non-null int64
# usertype                   975077 non-null object
# birth year                 975077 non-null int64
# gender                     975077 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(4)
# memory usage: 119.0+ MB

# %%
marchClean['stoptime'] = pd.to_datetime(marchClean.stoptime)
marchClean.info('stoptime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975077 entries, 0 to 976671
# Data columns (total 15 columns):
# tripduration               975077 non-null int64
# starttime                  975077 non-null datetime64[ns]
# stoptime                   975077 non-null datetime64[ns]
# start station id           975077 non-null int64
# start station name         975077 non-null object
# start station latitude     975077 non-null float64
# start station longitude    975077 non-null float64
# end station id             975077 non-null int64
# end station name           975077 non-null object
# end station latitude       975077 non-null float64
# end station longitude      975077 non-null float64
# bikeid                     975077 non-null int64
# usertype                   975077 non-null object
# birth year                 975077 non-null int64
# gender                     975077 non-null int64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(3)
# memory usage: 119.0+ MB

# %%
marchClean.gender[marchClean.gender == 0] = 'unknown'
marchClean.gender[marchClean.gender == 1] = 'male'
marchClean.gender[marchClean.gender == 2] = 'female'
marchClean
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         tripduration               starttime                stoptime  \
# 0                816 2018-03-01 02:29:13.727 2018-03-01 02:42:50.146
# 1                235 2018-03-01 05:12:37.032 2018-03-01 05:16:32.101
# 2               1250 2018-03-01 05:45:49.900 2018-03-01 06:06:39.908
# 3                741 2018-03-01 06:54:19.615 2018-03-01 07:06:40.979
# 4                727 2018-03-01 07:08:38.861 2018-03-01 07:20:46.850
# 5                341 2018-03-01 07:22:50.334 2018-03-01 07:28:31.904
# 6                697 2018-03-01 07:22:51.803 2018-03-01 07:34:29.243
# 7                407 2018-03-01 07:33:26.753 2018-03-01 07:40:14.156
# ...

# %%
dayOfWeek = marchClean.starttime.dt.weekday_name
marchClean['dayOfWeek'] = dayOfWeek
marchClean
# Out:
#         tripduration               starttime                stoptime  \
# 0                816 2018-03-01 02:29:13.727 2018-03-01 02:42:50.146
# 1                235 2018-03-01 05:12:37.032 2018-03-01 05:16:32.101
# 2               1250 2018-03-01 05:45:49.900 2018-03-01 06:06:39.908
# 3                741 2018-03-01 06:54:19.615 2018-03-01 07:06:40.979
# 4                727 2018-03-01 07:08:38.861 2018-03-01 07:20:46.850
# 5                341 2018-03-01 07:22:50.334 2018-03-01 07:28:31.904
# 6                697 2018-03-01 07:22:51.803 2018-03-01 07:34:29.243
# 7                407 2018-03-01 07:33:26.753 2018-03-01 07:40:14.156
# 8                978 2018-03-01 07:45:31.958 2018-03-01 08:01:50.642
# 9                396 2018-03-01 07:46:59.313 2018-03-01 07:53:35.564
# 10               284 2018-03-01 07:48:39.756 2018-03-01 07:53:24.656
# 11              1246 2018-03-01 08:19:17.579 2018-03-01 08:40:03.935
# 12                78 2018-03-01 08:27:09.236 2018-03-01 08:28:27.278
# ...

# %%
#marchClean.to_csv('marchCBClean.csv', mode = 'w', index=False)

# %%
# Import Data
file2 = "All CitiBike Data/201806-citibike-tripdata.csv"


juneCB = pd.read_csv(file2)

# %%
juneCB.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.953103e+06      1.953103e+06            1.953103e+06
# mean   1.211320e+03      1.587847e+03            4.073682e+01
# std    2.559797e+04      1.437212e+03            3.328542e-02
# min    6.100000e+01      7.200000e+01            4.065540e+01
# 25%    3.860000e+02      3.790000e+02            4.071689e+01
# 50%    6.600000e+02      5.040000e+02            4.073705e+01
# 75%    1.157000e+03      3.236000e+03            4.075763e+01
# max    7.571338e+06      3.692000e+03            4.550636e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.953103e+06    1.953103e+06          1.953103e+06
# mean             -7.398272e+01    1.580168e+03          4.073646e+01
# std               1.950168e-02    1.436349e+03          3.313123e-02
# min              -7.402535e+01    7.200000e+01          4.065540e+01
# ...

# %%
juneCB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953103 entries, 0 to 1953102
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  object
# stoptime                   object
# start station id           int64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             int64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 223.5+ MB

# %%
juneCB.shape
# Out:
# (1953103, 15)

# %%
juneCB.gender.value_counts(dropna=False)
# Out:
# 1    1281908
# 2     469544
# 0     201651
# Name: gender, dtype: int64

# %%
juneCB.usertype.value_counts(dropna=False)
# Out:
# Subscriber    1694788
# Customer       258315
# Name: usertype, dtype: int64

# %%
juneCB.bikeid.value_counts(dropna=False)
# Out:
# 30202    404
# 33218    397
# 33667    396
# 32511    392
# 33239    389
# 30982    381
# 28382    381
# 30794    375
# 32381    374
# 31351    373
# 31236    372
# 30205    372
# 29965    371
# 30168    371
# 32252    368
# 32943    368
# 32097    368
# 33251    368
# 32300    367
# 30163    365
# 32261    364
# 31578    364
# 32222    364
# 30728    363
# 32048    362
# 33162    362
# 30682    362
# 31102    359
# 33175    358
# 31552    357
#         ...
# 16397      2
# 15086      2
# 26395      2
# 15266      2
# 25640      2
# 16949      2
# 33600      2
# 19105      2
# 27205      2
# 21152      2
# 28453      2
# 19706      2
# 20202      2
# 27922      2
# 28287      2
# 18571      2
# 18531      2
# 18575      1
# 27241      1
# 33111      1
# 32859      1
# 15506      1
# 20721      1
# 27640      1
# 20024      1
# 17757      1
# 20162      1
# 21940      1
# 15062      1
# 33146      1
# Name: bikeid, Length: 11889, dtype: int64

# %%
juneCB.min()
# Out:
# tripduration                                     61
# starttime                  2018-06-01 00:00:02.4580
# stoptime                   2018-06-01 00:03:32.7080
# start station id                                 72
# start station name                 1 Ave & E 110 St
# start station latitude                      40.6554
# start station longitude                    -74.0254
# end station id                                   72
# end station name                   1 Ave & E 110 St
# end station latitude                        40.6554
# end station longitude                      -74.0557
# bikeid                                        14529
# usertype                                   Customer
# birth year                                     1885
# gender                                            0
# dtype: object

# %%
juneCB.max()
# Out:
# tripduration                                7571338
# starttime                  2018-06-30 23:59:54.3620
# stoptime                   2018-09-05 14:51:22.8480
# start station id                               3692
# start station name            Yankee Ferry Terminal
# start station latitude                      45.5064
# start station longitude                    -73.5689
# end station id                                 3692
# end station name              Yankee Ferry Terminal
# end station latitude                        45.5064
# end station longitude                      -73.5689
# bikeid                                        33699
# usertype                                 Subscriber
# birth year                                     2002
# gender                                            2
# dtype: object

# %%
juneCB['birth year'].min()
# Out:
# 1885

# %%
juneCB['tripduration'].median()
# Out:
# 660.0

# %%
juneCB['birth year'].tail()
# Out:
# 1953098    1996
# 1953099    1972
# 1953100    1984
# 1953101    1969
# 1953102    1971
# Name: birth year, dtype: int64

# %%
# birth year small problem or large
birthyearsort =juneCB.sort_values('birth year', ascending = True)
birthyearsort.head(100)
# Out:
#          tripduration                 starttime                  stoptime  \
# 1753630           647  2018-06-03 13:12:46.4720  2018-06-03 13:23:34.1270
# 1026834           539  2018-06-15 09:49:38.3290  2018-06-15 09:58:38.2350
# 733008            826  2018-06-15 11:59:32.8200  2018-06-15 12:13:19.0050
# 1766841           737  2018-06-20 16:48:26.6300  2018-06-20 17:00:43.8040
# 1756879           998  2018-06-25 15:27:05.7790  2018-06-25 15:43:44.1550
# 931584           1174  2018-06-09 10:44:51.8710  2018-06-09 11:04:26.4900
# 1756731           937  2018-06-24 13:00:13.3260  2018-06-24 13:15:50.5550
# 726422            490  2018-06-05 07:28:07.2340  2018-06-05 07:36:18.2290
# 269775            604  2018-06-12 12:34:01.5230  2018-06-12 12:44:05.8530
# 1754741           407  2018-06-10 15:22:20.1650  2018-06-10 15:29:08.0550
# 493082           1429  2018-06-20 17:50:41.4990  2018-06-20 18:14:31.0940
# 1034751          1222  2018-06-02 09:26:12.4620  2018-06-02 09:46:35.0630
# ...

# %%
# isolate those rows whose birth year is older than 100 yo

juneCB.loc[juneCB['birth year'] < 1919]
# Out:
#          tripduration                 starttime                  stoptime  \
# 312               804  2018-06-03 13:13:05.3760  2018-06-03 13:26:29.7660
# 6054              320  2018-06-14 17:41:13.8480  2018-06-14 17:46:33.8490
# 6107              575  2018-06-15 07:57:56.0360  2018-06-15 08:07:32.0290
# 6207              529  2018-06-15 19:03:16.2420  2018-06-15 19:12:05.6640
# 6545              190  2018-06-19 18:32:13.0170  2018-06-19 18:35:23.7120
# 6948              313  2018-06-22 17:55:37.3330  2018-06-22 18:00:51.2790
# 6979              938  2018-06-23 07:54:59.6490  2018-06-23 08:10:37.6810
# 6983              294  2018-06-23 09:38:39.3700  2018-06-23 09:43:33.4010
# 7319              266  2018-06-26 17:49:45.9210  2018-06-26 17:54:12.9160
# 7435              281  2018-06-27 17:25:30.8840  2018-06-27 17:30:12.5450
# 7667              461  2018-06-29 18:41:24.5130  2018-06-29 18:49:05.5390
# 10093            2168  2018-06-20 19:52:33.8020  2018-06-20 20:28:42.6740
# ...

# %%
# remove 1374 rows of data for all people older than 100

juneBY = juneCB.drop(juneCB[juneCB['birth year'] < 1919].index)

# %%
juneBY['birth year'].min()
# Out:
# 1919

# %%
juneBY['birth year'].max()
# Out:
# 2002

# %%
# isolating trips greater than 4 hours. 

juneBY.loc[juneBY['tripduration'] > 15000]
# Out:
#          tripduration                 starttime                  stoptime  \
# 767             18185  2018-06-06 15:34:07.1730  2018-06-06 20:37:12.2420
# 2541            20043  2018-06-17 13:36:41.0310  2018-06-17 19:10:44.9070
# 3434            58785  2018-06-22 20:16:45.5490  2018-06-23 12:36:31.1500
# 4821           231037  2018-06-03 22:08:03.1840  2018-06-06 14:18:40.7300
# 6240            28433  2018-06-16 01:35:59.2920  2018-06-16 09:29:52.8620
# 6266            19565  2018-06-16 12:43:56.0710  2018-06-16 18:10:01.1100
# 6376            43749  2018-06-17 19:32:43.6920  2018-06-18 07:41:53.4260
# 6950            71503  2018-06-22 18:04:40.7930  2018-06-23 13:56:24.3440
# 7018            15301  2018-06-23 14:26:07.8130  2018-06-23 18:41:08.9260
# 7356            22179  2018-06-26 23:21:01.5740  2018-06-27 05:30:40.9830
# 8967          5891578  2018-06-02 13:13:38.5970  2018-08-09 17:46:37.2720
# 9556           767065  2018-06-12 17:34:23.4330  2018-06-21 14:38:48.5830
# ...

# %%
# remove 2792 rows of data for trips greater than four hours. 
juneClean = juneBY.drop(juneBY[juneBY['tripduration'] > 15000].index)
juneClean.shape
# Out:
# (1948937, 15)

# %%
juneClean['tripduration'].max()
# Out:
# 14999

# %%
juneClean.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.948937e+06      1.948937e+06            1.948937e+06
# mean   8.858298e+02      1.587164e+03            4.073682e+01
# std    8.382681e+02      1.437060e+03            3.309824e-02
# min    6.100000e+01      7.200000e+01            4.065540e+01
# 25%    3.850000e+02      3.790000e+02            4.071689e+01
# 50%    6.590000e+02      5.040000e+02            4.073705e+01
# 75%    1.154000e+03      3.236000e+03            4.075763e+01
# max    1.499900e+04      3.692000e+03            4.550636e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.948937e+06    1.948937e+06          1.948937e+06
# mean             -7.398273e+01    1.579257e+03          4.073647e+01
# std               1.949100e-02    1.436137e+03          3.294392e-02
# min              -7.402535e+01    7.200000e+01          4.065540e+01
# ...

# %%
juneClean['starttime'] = pd.to_datetime(juneClean.starttime)
juneClean.info('starttime')
juneClean['stoptime'] = pd.to_datetime(juneClean.stoptime)
juneClean.info('stoptime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1948937 entries, 0 to 1953102
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   object
# start station id           int64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             int64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(4)
# memory usage: 237.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1948937 entries, 0 to 1953102
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# ...

# %%
juneClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1948937 entries, 0 to 1953102
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id           int64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             int64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(3)
# memory usage: 237.9+ MB

# %%
juneClean.gender[juneClean.gender == 0] = 'unknown'
juneClean.gender[juneClean.gender == 1] = 'male'
juneClean.gender[juneClean.gender == 2] = 'female'
juneClean
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          tripduration               starttime                stoptime  \
# 0                 569 2018-06-01 01:57:20.514 2018-06-01 02:06:50.088
# 1                 480 2018-06-01 02:02:42.398 2018-06-01 02:10:43.354
# 2                 692 2018-06-01 02:04:23.624 2018-06-01 02:15:55.747
# 3                 664 2018-06-01 03:00:55.461 2018-06-01 03:11:59.906
# 4                 818 2018-06-01 06:04:54.427 2018-06-01 06:18:32.617
# 5                 753 2018-06-01 06:11:52.599 2018-06-01 06:24:26.198
# 6                 687 2018-06-01 07:15:15.565 2018-06-01 07:26:42.867
# 7                 619 2018-06-01 07:40:02.578 2018-06-01 07:50:22.028
# ...

# %%
dayOfWeek = juneClean.starttime.dt.weekday_name
juneClean['dayOfWeek'] = dayOfWeek
juneClean
# Out:
#          tripduration               starttime                stoptime  \
# 0                 569 2018-06-01 01:57:20.514 2018-06-01 02:06:50.088
# 1                 480 2018-06-01 02:02:42.398 2018-06-01 02:10:43.354
# 2                 692 2018-06-01 02:04:23.624 2018-06-01 02:15:55.747
# 3                 664 2018-06-01 03:00:55.461 2018-06-01 03:11:59.906
# 4                 818 2018-06-01 06:04:54.427 2018-06-01 06:18:32.617
# 5                 753 2018-06-01 06:11:52.599 2018-06-01 06:24:26.198
# 6                 687 2018-06-01 07:15:15.565 2018-06-01 07:26:42.867
# 7                 619 2018-06-01 07:40:02.578 2018-06-01 07:50:22.028
# 8                 819 2018-06-01 07:43:01.958 2018-06-01 07:56:41.328
# 9                 335 2018-06-01 07:49:47.934 2018-06-01 07:55:23.309
# 10                325 2018-06-01 07:52:11.922 2018-06-01 07:57:37.618
# 11               1030 2018-06-01 07:52:49.933 2018-06-01 08:10:00.412
# ...

# %%
juneClean['starttime'].max()
# Out:
# Timestamp('2018-06-30 23:59:54.362000')

# %%
juneClean['starttime'].min()
# Out:
# Timestamp('2018-06-01 00:00:02.458000')

# %%
juneClean['stoptime'].max()
# Out:
# Timestamp('2018-07-01 02:04:32.436000')

# %%
juneClean['stoptime'].min()
# Out:
# Timestamp('2018-06-01 00:03:32.708000')

# %%
#juneClean.to_csv('juneCBClean.csv', mode = 'w', index=False)

# %%
# Import Data
file3 = "All CitiBike Data/201809-citibike-tripdata.csv"

# %%
septCB = pd.read_csv(file3)

# %%
septCB.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.877884e+06      1.877168e+06            1.877884e+06
# mean   9.675149e+02      1.641635e+03            4.073710e+01
# std    7.893692e+03      1.454014e+03            3.115605e-02
# min    6.100000e+01      7.200000e+01            4.064654e+01
# 25%    3.750000e+02      3.820000e+02            4.071740e+01
# 50%    6.400000e+02      5.140000e+02            4.073705e+01
# 75%    1.129000e+03      3.263000e+03            4.075892e+01
# max    2.431651e+06      3.705000e+03            4.086900e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.877884e+06    1.877168e+06          1.877884e+06
# mean             -7.398237e+01    1.634439e+03          4.073674e+01
# std               1.971399e-02    1.453672e+03          3.097150e-02
# min              -7.402535e+01    7.200000e+01          4.064654e+01
# ...

# %%
septCB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1877884 entries, 0 to 1877883
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  object
# stoptime                   object
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 214.9+ MB

# %%
septCB.shape
# Out:
# (1877884, 15)

# %%
septCB.gender.value_counts(dropna=False)
# Out:
# 1    1240964
# 2     463433
# 0     173487
# Name: gender, dtype: int64

# %%
septCB.usertype.value_counts(dropna=False)
# Out:
# Subscriber    1616731
# Customer       261153
# Name: usertype, dtype: int64

# %%
septCB.bikeid.value_counts(dropna=False)
# Out:
# 33875    559
# 33772    549
# 34357    549
# 33868    533
# 33878    532
# 34232    528
# 33927    527
# 34256    522
# 34000    521
# 33931    514
# 34135    513
# 33956    513
# 34258    513
# 34093    511
# 33989    508
# 34020    505
# 34419    504
# 34119    504
# 34397    502
# 33782    501
# 33823    501
# 34386    500
# 34076    497
# 34203    497
# 33762    496
# 33963    496
# 33789    495
# 33897    495
# 33860    495
# 34322    494
#         ...
# 19411      2
# 34577      2
# 34894      2
# 34429      2
# 31617      1
# 34539      1
# 24763      1
# 25612      1
# 30757      1
# 30475      1
# 27401      1
# 33184      1
# 34622      1
# 34904      1
# 34569      1
# 34474      1
# 34460      1
# 28520      1
# 19420      1
# 34508      1
# 34886      1
# 34623      1
# 25299      1
# 34544      1
# 19073      1
# 34867      1
# 15834      1
# 32379      1
# 34431      1
# 29726      1
# Name: bikeid, Length: 10892, dtype: int64

# %%
septCB.min()
# Out:
# tripduration                                     61
# starttime                  2018-09-01 00:00:05.2690
# stoptime                   2018-09-01 00:02:23.4810
# start station id                                 72
# start station latitude                      40.6465
# start station longitude                    -74.0254
# end station id                                   72
# end station latitude                        40.6465
# end station longitude                      -74.0836
# bikeid                                        14529
# usertype                                   Customer
# birth year                                     1885
# gender                                            0
# dtype: object

# %%
septCB.max()
# Out:
# tripduration                                2431651
# starttime                  2018-09-30 23:59:56.4460
# stoptime                   2018-10-03 14:10:13.1770
# start station id                               3705
# start station latitude                       40.869
# start station longitude                     -73.878
# end station id                                 3705
# end station latitude                         40.869
# end station longitude                       -73.878
# bikeid                                        34907
# usertype                                 Subscriber
# birth year                                     2002
# gender                                            2
# dtype: object

# %%
septCB['birth year'].min()
# Out:
# 1885

# %%
septCB['tripduration'].median()
# Out:
# 640.0

# %%
septCB['birth year'].head()
# Out:
# 0    1980
# 1    1969
# 2    1975
# 3    1984
# 4    1994
# Name: birth year, dtype: int64

# %%
# birth year small problem or large
birthyearsort = septCB.sort_values('birth year', ascending = True)
birthyearsort.head(100)
# Out:
#          tripduration                 starttime                  stoptime  \
# 283877            812  2018-09-05 17:08:21.8610  2018-09-05 17:21:54.7040
# 68371            1200  2018-09-02 12:06:40.6970  2018-09-02 12:26:41.0780
# 8904              398  2018-09-01 10:35:36.5840  2018-09-01 10:42:14.7020
# 485437            992  2018-09-08 13:42:59.3640  2018-09-08 13:59:31.9050
# 1754926          1347  2018-09-29 10:57:30.3170  2018-09-29 11:19:57.5170
# 1829158           826  2018-09-30 12:15:40.7690  2018-09-30 12:29:27.4210
# 924719            351  2018-09-16 13:16:02.9450  2018-09-16 13:21:54.4330
# 124304            596  2018-09-03 10:42:04.7320  2018-09-03 10:52:01.0980
# 489812           1494  2018-09-08 14:31:30.5860  2018-09-08 14:56:24.9270
# 975361            592  2018-09-17 07:33:17.9190  2018-09-17 07:43:10.2070
# 1495500           728  2018-09-24 17:59:08.7920  2018-09-24 18:11:16.8270
# 1405054          1002  2018-09-23 12:18:15.3550  2018-09-23 12:34:58.1640
# ...

# %%
# isolate those rows whose birth year is older than 100 yo

septCB.loc[septCB['birth year'] < 1919]
# Out:
#          tripduration                 starttime                  stoptime  \
# 457               250  2018-09-01 00:33:19.8080  2018-09-01 00:37:29.9270
# 734               168  2018-09-01 00:57:20.5560  2018-09-01 01:00:08.8620
# 2449              276  2018-09-01 06:48:35.0800  2018-09-01 06:53:11.3010
# 2715              286  2018-09-01 07:16:25.8630  2018-09-01 07:21:12.4050
# 3533             1286  2018-09-01 08:11:37.4930  2018-09-01 08:33:04.4290
# 4877              243  2018-09-01 09:02:33.1020  2018-09-01 09:06:36.5580
# 5188              548  2018-09-01 09:12:11.4520  2018-09-01 09:21:19.8160
# 5236             1729  2018-09-01 09:13:54.5670  2018-09-01 09:42:43.6350
# 5542              714  2018-09-01 09:23:25.4370  2018-09-01 09:35:19.7980
# 6440             1369  2018-09-01 09:46:12.8450  2018-09-01 10:09:01.9850
# 8904              398  2018-09-01 10:35:36.5840  2018-09-01 10:42:14.7020
# 9249             3562  2018-09-01 10:41:32.8500  2018-09-01 11:40:55.0920
# ...

# %%
# remove 962 rows of data for all people older than 100

septBY = septCB.drop(septCB[septCB['birth year'] < 1919].index)

# %%
septBY['birth year'].min()
# Out:
# 1919

# %%
septBY['tripduration'].max()
# Out:
# 2431651

# %%
# isolating trips greater than 4 hours. 

septBY.loc[septBY['tripduration'] > 15000]
# Out:
#          tripduration                 starttime                  stoptime  \
# 94              37428  2018-09-01 00:06:45.1410  2018-09-01 10:30:33.2080
# 754             35777  2018-09-01 00:59:43.8320  2018-09-01 10:56:01.2460
# 1242           479158  2018-09-01 01:50:21.6230  2018-09-06 14:56:19.8110
# 1700            22594  2018-09-01 03:00:25.1080  2018-09-01 09:16:59.8800
# 1704            31257  2018-09-01 03:01:38.1730  2018-09-01 11:42:36.1550
# 1721            27836  2018-09-01 03:06:25.3100  2018-09-01 10:50:21.8320
# 1745            87585  2018-09-01 03:10:22.2010  2018-09-02 03:30:08.1490
# 1842            62911  2018-09-01 03:36:07.2050  2018-09-01 21:04:38.9990
# 2238           145958  2018-09-01 06:06:26.5590  2018-09-02 22:39:05.0050
# 2958            16072  2018-09-01 07:38:43.1650  2018-09-01 12:06:35.6460
# 4951            19796  2018-09-01 09:04:33.5360  2018-09-01 14:34:29.8240
# 5068           125274  2018-09-01 09:08:39.9560  2018-09-02 19:56:34.7340
# ...

# %%
# remove 1773 rows of data for trips greater than four hours. 
septClean = septBY.drop(septBY[septBY['tripduration'] > 15000].index)

# %%
septClean['tripduration'].max()
# Out:
# 14990

# %%
septClean['starttime'] = pd.to_datetime(septClean.starttime)
septClean.info('starttime')
septClean['stoptime'] = pd.to_datetime(septClean.stoptime)
septClean.info('stoptime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1875149 entries, 0 to 1877883
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   object
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(4)
# memory usage: 228.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1875149 entries, 0 to 1877883
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# ...

# %%
septClean.gender[septClean.gender == 0] = 'unknown'
septClean.gender[septClean.gender == 1] = 'male'
septClean.gender[septClean.gender == 2] = 'female'
septClean
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          tripduration               starttime                stoptime  \
# 0                1635 2018-09-01 00:00:05.269 2018-09-01 00:27:20.634
# 1                 132 2018-09-01 00:00:11.281 2018-09-01 00:02:23.481
# 2                3337 2018-09-01 00:00:20.649 2018-09-01 00:55:58.547
# 3                 436 2018-09-01 00:00:21.746 2018-09-01 00:07:38.583
# 4                8457 2018-09-01 00:00:27.315 2018-09-01 02:21:25.308
# 5                3326 2018-09-01 00:00:29.303 2018-09-01 00:55:56.202
# 6                 233 2018-09-01 00:00:27.278 2018-09-01 00:04:20.742
# 7                 285 2018-09-01 00:00:31.425 2018-09-01 00:05:17.411
# ...

# %%
dayOfWeek = marchClean.starttime.dt.weekday_name
septClean['dayOfWeek'] = dayOfWeek
septClean
# Out:
#          tripduration               starttime                stoptime  \
# 0                1635 2018-09-01 00:00:05.269 2018-09-01 00:27:20.634
# 1                 132 2018-09-01 00:00:11.281 2018-09-01 00:02:23.481
# 2                3337 2018-09-01 00:00:20.649 2018-09-01 00:55:58.547
# 3                 436 2018-09-01 00:00:21.746 2018-09-01 00:07:38.583
# 4                8457 2018-09-01 00:00:27.315 2018-09-01 02:21:25.308
# 5                3326 2018-09-01 00:00:29.303 2018-09-01 00:55:56.202
# 6                 233 2018-09-01 00:00:27.278 2018-09-01 00:04:20.742
# 7                 285 2018-09-01 00:00:31.425 2018-09-01 00:05:17.411
# 8                1127 2018-09-01 00:00:30.966 2018-09-01 00:19:18.471
# 9                 423 2018-09-01 00:00:42.167 2018-09-01 00:07:45.677
# 10                327 2018-09-01 00:00:45.248 2018-09-01 00:06:12.272
# 11                541 2018-09-01 00:00:45.784 2018-09-01 00:09:47.047
# ...

# %%
septClean.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.875149e+06      1.874449e+06            1.875149e+06
# mean   8.666282e+02      1.641235e+03            4.073710e+01
# std    8.198995e+02      1.453955e+03            3.114491e-02
# min    6.100000e+01      7.200000e+01            4.064654e+01
# 25%    3.740000e+02      3.820000e+02            4.071740e+01
# 50%    6.390000e+02      5.140000e+02            4.073705e+01
# 75%    1.127000e+03      3.263000e+03            4.075892e+01
# max    1.499000e+04      3.705000e+03            4.086900e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.875149e+06    1.874449e+06          1.875149e+06
# mean             -7.398238e+01    1.633965e+03          4.073675e+01
# std               1.970659e-02    1.453599e+03          3.095916e-02
# min              -7.402535e+01    7.200000e+01          4.064654e+01
# ...

# %%
septClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1875149 entries, 0 to 1877883
# Data columns (total 16 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     object
# dayOfWeek                  object
# dtypes: datetime64[ns](2), float64(6), int64(3), object(5)
# memory usage: 243.2+ MB

# %%
septClean['starttime'].min()
# Out:
# Timestamp('2018-09-01 00:00:05.269000')

# %%
septClean['starttime'].max()
# Out:
# Timestamp('2018-09-30 23:59:56.446000')

# %%
septClean['stoptime'].min()
# Out:
# Timestamp('2018-09-01 00:02:23.481000')

# %%
septClean['stoptime'].max()
# Out:
# Timestamp('2018-10-01 01:47:32.844000')

# %%
#septClean.to_csv('septCBClean.csv', mode = 'w',  index=False)

# %%
# Import Data
file4 = "All CitiBike Data/201812-citibike-tripdata.csv"

# %%
decCB = pd.read_csv(file4)

# %%
decCB.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.016505e+06      1.016416e+06            1.016505e+06
# mean   8.230674e+02      1.628852e+03            4.073755e+01
# std    7.505748e+03      1.454875e+03            3.043334e-02
# min    6.100000e+01      7.200000e+01            4.064654e+01
# 25%    3.260000e+02      3.850000e+02            4.071882e+01
# 50%    5.340000e+02      5.090000e+02            4.073913e+01
# 75%    9.020000e+02      3.263000e+03            4.075757e+01
# max    3.168629e+06      3.721000e+03            4.086900e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.016505e+06    1.016416e+06          1.016505e+06
# mean             -7.398204e+01    1.618289e+03          4.073733e+01
# std               1.862205e-02    1.453710e+03          3.013523e-02
# min              -7.401713e+01    7.200000e+01          4.064654e+01
# ...

# %%
decCB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016505 entries, 0 to 1016504
# Data columns (total 15 columns):
# tripduration               1016505 non-null int64
# starttime                  1016505 non-null object
# stoptime                   1016505 non-null object
# start station id           1016416 non-null float64
# start station name         1016416 non-null object
# start station latitude     1016505 non-null float64
# start station longitude    1016505 non-null float64
# end station id             1016416 non-null float64
# end station name           1016416 non-null object
# end station latitude       1016505 non-null float64
# end station longitude      1016505 non-null float64
# bikeid                     1016505 non-null int64
# usertype                   1016505 non-null object
# birth year                 1016505 non-null int64
# gender                     1016505 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 116.3+ MB

# %%
decCB.shape
# Out:
# (1016505, 15)

# %%
decCB.gender.value_counts(dropna=False)
# Out:
# 1    746622
# 2    223675
# 0     46208
# Name: gender, dtype: int64

# %%
decCB.usertype.value_counts(dropna=False)
# Out:
# Subscriber    955408
# Customer       61097
# Name: usertype, dtype: int64

# %%
decCB.bikeid.value_counts(dropna=False)
# Out:
# 35436    462
# 35561    455
# 35578    445
# 34726    444
# 34720    429
# 35564    425
# 34784    424
# 35563    417
# 34868    416
# 35540    413
# 35440    411
# 34734    406
# 34822    404
# 35535    397
# 34654    396
# 34756    396
# 34683    394
# 34870    394
# 35562    391
# 34861    391
# 34852    390
# 35537    386
# 35558    384
# 34761    383
# 34766    380
# 35556    380
# 35551    376
# 34650    375
# 34814    374
# 34719    373
#         ...
# 17799      1
# 29408      1
# 25273      1
# 20208      1
# 28233      1
# 35591      1
# 27145      1
# 34898      1
# 18854      1
# 17575      1
# 26793      1
# 21569      1
# 26935      1
# 35626      1
# 20803      1
# 21186      1
# 21250      1
# 24861      1
# 34554      1
# 33155      1
# 30272      1
# 19194      1
# 26825      1
# 20607      1
# 14532      1
# 18339      1
# 19176      1
# 19293      1
# 28162      1
# 25445      1
# Name: bikeid, Length: 13046, dtype: int64

# %%
decCB.min()
# Out:
# tripduration                                     61
# starttime                  2018-12-01 00:00:04.3020
# stoptime                   2018-12-01 00:03:30.5230
# start station id                                 72
# start station latitude                      40.6465
# start station longitude                    -74.0171
# end station id                                   72
# end station latitude                        40.6465
# end station longitude                      -74.0557
# bikeid                                        14529
# usertype                                   Customer
# birth year                                     1885
# gender                                            0
# dtype: object

# %%
decCB.max()
# Out:
# tripduration                                3168629
# starttime                  2018-12-31 23:59:51.0850
# stoptime                   2019-01-08 08:39:45.0180
# start station id                               3721
# start station latitude                       40.869
# start station longitude                     -73.878
# end station id                                 3721
# end station latitude                         40.869
# end station longitude                       -73.878
# bikeid                                        35831
# usertype                                 Subscriber
# birth year                                     2002
# gender                                            2
# dtype: object

# %%
decCB['birth year'].min()
# Out:
# 1885

# %%
decCB['tripduration'].median()
# Out:
# 534.0

# %%
decCB['birth year'].head()
# Out:
# 0    1989
# 1    1966
# 2    1984
# 3    1983
# 4    1976
# Name: birth year, dtype: int64

# %%
# birth year small problem or large
birthyearsort = decCB.sort_values('birth year', ascending = True)
birthyearsort.head(100)
# Out:
#         tripduration                 starttime                  stoptime  \
# 978613           644  2018-12-30 10:19:16.0420  2018-12-30 10:30:00.0850
# 585651          1060  2018-12-15 14:12:30.9590  2018-12-15 14:30:11.1650
# 24455            656  2018-12-01 15:20:47.3420  2018-12-01 15:31:43.3600
# 6362             583  2018-12-01 10:06:25.1590  2018-12-01 10:16:09.0300
# 94197            738  2018-12-03 17:56:26.7990  2018-12-03 18:08:45.4330
# 5335            1107  2018-12-01 09:42:32.0160  2018-12-01 10:00:59.6160
# 581295          1310  2018-12-15 12:50:25.3040  2018-12-15 13:12:15.6300
# 8026             985  2018-12-01 10:43:41.8290  2018-12-01 11:00:07.3270
# 338278           882  2018-12-09 15:34:22.2680  2018-12-09 15:49:04.5780
# 338869           635  2018-12-09 15:49:38.3040  2018-12-09 16:00:13.8020
# 48443            330  2018-12-02 16:16:26.9610  2018-12-02 16:21:57.2000
# 33002            170  2018-12-01 18:13:20.3430  2018-12-01 18:16:10.3920
# ...

# %%
# isolate those rows whose birth year is older than 100 yo

decCB.loc[decCB['birth year'] < 1919]
# Out:
#          tripduration                 starttime                  stoptime  \
# 184               271  2018-12-01 00:15:55.7050  2018-12-01 00:20:27.6700
# 256              1757  2018-12-01 00:22:33.4330  2018-12-01 00:51:51.1540
# 519               160  2018-12-01 00:48:37.1850  2018-12-01 00:51:18.1370
# 560               639  2018-12-01 00:54:04.5550  2018-12-01 01:04:44.5110
# 3929              558  2018-12-01 08:59:12.5100  2018-12-01 09:08:31.3840
# 5335             1107  2018-12-01 09:42:32.0160  2018-12-01 10:00:59.6160
# 6362              583  2018-12-01 10:06:25.1590  2018-12-01 10:16:09.0300
# 6908              748  2018-12-01 10:18:54.3460  2018-12-01 10:31:22.7070
# 7693              452  2018-12-01 10:36:23.2550  2018-12-01 10:43:55.7010
# 8026              985  2018-12-01 10:43:41.8290  2018-12-01 11:00:07.3270
# 13080             373  2018-12-01 12:15:21.6300  2018-12-01 12:21:34.6750
# 17823             319  2018-12-01 13:30:51.8520  2018-12-01 13:36:11.5730
# ...

# %%
# remove 845 rows of data for all people older than 100

decBY = decCB.drop(decCB[decCB['birth year'] < 1919].index)

# %%
decBY['birth year'].min()
# Out:
# 1919

# %%
decBY['tripduration'].max()
# Out:
# 3168629

# %%
# isolating trips greater than 4 hours. 

decBY.loc[decBY['tripduration'] > 15000]
# Out:
#          tripduration                 starttime                  stoptime  \
# 8               43287  2018-12-01 00:00:49.8680  2018-12-01 12:02:16.9530
# 299             44465  2018-12-01 00:27:01.7440  2018-12-01 12:48:06.8850
# 539             43489  2018-12-01 00:51:04.7440  2018-12-01 12:55:54.4450
# 897           1797685  2018-12-01 01:33:21.3870  2018-12-21 20:54:47.1790
# 915             46636  2018-12-01 01:35:19.3910  2018-12-01 14:32:36.2030
# 1243            30059  2018-12-01 02:41:01.7080  2018-12-01 11:02:01.6600
# 1436            40684  2018-12-01 03:45:53.1070  2018-12-01 15:03:57.2680
# 1455           118210  2018-12-01 03:53:11.3700  2018-12-02 12:43:22.0740
# 1745            45911  2018-12-01 06:18:57.3970  2018-12-01 19:04:09.2360
# 5617            84831  2018-12-01 09:48:23.8670  2018-12-02 09:22:15.4810
# 6585            19611  2018-12-01 10:11:46.4710  2018-12-01 15:38:37.5160
# 6586            18016  2018-12-01 10:11:46.3270  2018-12-01 15:12:02.3830
# ...

# %%
# remove 1024 rows of data for trips greater than four hours. 
decClean = decBY.drop(decBY[decBY['tripduration'] > 15000].index)

# %%
decClean['tripduration'].max()
# Out:
# 14986

# %%
decClean['starttime'] = pd.to_datetime(decClean.starttime)
decClean.info('starttime')
decClean['stoptime'] = pd.to_datetime(decClean.stoptime)
decClean.info('stoptime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1014636 entries, 0 to 1016504
# Data columns (total 15 columns):
# tripduration               1014636 non-null int64
# starttime                  1014636 non-null datetime64[ns]
# stoptime                   1014636 non-null object
# start station id           1014548 non-null float64
# start station name         1014548 non-null object
# start station latitude     1014636 non-null float64
# start station longitude    1014636 non-null float64
# end station id             1014548 non-null float64
# end station name           1014548 non-null object
# end station latitude       1014636 non-null float64
# end station longitude      1014636 non-null float64
# bikeid                     1014636 non-null int64
# usertype                   1014636 non-null object
# birth year                 1014636 non-null int64
# gender                     1014636 non-null int64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(4)
# ...

# %%
decClean.gender[decClean.gender == 0] = 'unknown'
decClean.gender[decClean.gender == 1] = 'male'
decClean.gender[decClean.gender == 2] = 'female'
decClean
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          tripduration               starttime                stoptime  \
# 0                 689 2018-12-01 00:00:04.302 2018-12-01 00:11:33.846
# 1                 204 2018-12-01 00:00:05.533 2018-12-01 00:03:30.523
# 2                 316 2018-12-01 00:00:10.233 2018-12-01 00:05:27.203
# 3                 726 2018-12-01 00:00:21.957 2018-12-01 00:12:28.183
# 4                 397 2018-12-01 00:00:29.632 2018-12-01 00:07:07.446
# 5                 299 2018-12-01 00:00:30.865 2018-12-01 00:05:30.636
# 6                 414 2018-12-01 00:00:34.687 2018-12-01 00:07:29.341
# 7                 216 2018-12-01 00:00:39.929 2018-12-01 00:04:16.729
# ...

# %%
dayOfWeek = decClean.starttime.dt.weekday_name
decClean['dayOfWeek'] = dayOfWeek
decClean
# Out:
#          tripduration               starttime                stoptime  \
# 0                 689 2018-12-01 00:00:04.302 2018-12-01 00:11:33.846
# 1                 204 2018-12-01 00:00:05.533 2018-12-01 00:03:30.523
# 2                 316 2018-12-01 00:00:10.233 2018-12-01 00:05:27.203
# 3                 726 2018-12-01 00:00:21.957 2018-12-01 00:12:28.183
# 4                 397 2018-12-01 00:00:29.632 2018-12-01 00:07:07.446
# 5                 299 2018-12-01 00:00:30.865 2018-12-01 00:05:30.636
# 6                 414 2018-12-01 00:00:34.687 2018-12-01 00:07:29.341
# 7                 216 2018-12-01 00:00:39.929 2018-12-01 00:04:16.729
# 9                 363 2018-12-01 00:00:57.807 2018-12-01 00:07:01.076
# 10                807 2018-12-01 00:01:06.134 2018-12-01 00:14:33.539
# 11                266 2018-12-01 00:00:55.687 2018-12-01 00:05:22.104
# 12                931 2018-12-01 00:01:33.101 2018-12-01 00:17:04.115
# ...

# %%
decClean['starttime'].min()
# Out:
# Timestamp('2018-12-01 00:00:04.302000')

# %%
decClean['starttime'].max()
# Out:
# Timestamp('2018-12-31 23:59:51.085000')

# %%
decClean['stoptime'].min()
# Out:
# Timestamp('2018-12-01 00:03:30.523000')

# %%
decClean['stoptime'].max()
# Out:
# Timestamp('2019-01-01 01:45:50.842000')

# %%
decClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1014636 entries, 0 to 1016504
# Data columns (total 16 columns):
# tripduration               1014636 non-null int64
# starttime                  1014636 non-null datetime64[ns]
# stoptime                   1014636 non-null datetime64[ns]
# start station id           1014548 non-null float64
# start station name         1014548 non-null object
# start station latitude     1014636 non-null float64
# start station longitude    1014636 non-null float64
# end station id             1014548 non-null float64
# end station name           1014548 non-null object
# end station latitude       1014636 non-null float64
# end station longitude      1014636 non-null float64
# bikeid                     1014636 non-null int64
# usertype                   1014636 non-null object
# birth year                 1014636 non-null int64
# gender                     1014636 non-null object
# dayOfWeek                  1014636 non-null object
# ...

# %%
#decClean.to_csv('decCBClean.csv', mode = 'w', index=False)

# %%
first2CBdata = marchClean.append(juneClean)
first2CBdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2924014 entries, 0 to 1953102
# Data columns (total 16 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id           int64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             int64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     object
# dayOfWeek                  object
# dtypes: datetime64[ns](2), float64(4), int64(5), object(5)
# memory usage: 379.2+ MB

# %%
second2CBdata = septClean.append(decClean)
second2CBdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2889785 entries, 0 to 1016504
# Data columns (total 16 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     object
# dayOfWeek                  object
# dtypes: datetime64[ns](2), float64(6), int64(3), object(5)
# memory usage: 374.8+ MB

# %%
allCBdata = first2CBdata.append(second2CBdata)
allCBdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5813799 entries, 0 to 1016504
# Data columns (total 16 columns):
# tripduration               int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     object
# dayOfWeek                  object
# dtypes: datetime64[ns](2), float64(6), int64(3), object(5)
# memory usage: 754.0+ MB

# %%
allCBdata.shape
# Out:
# (5813799, 16)

# %%
allCBdata.gender.value_counts(dropna=False)
# Out:
# male       3966398
# female     1367732
# unknown     479669
# Name: gender, dtype: int64

# %%
stationMapData = allCBdata.iloc[: , [1, 2, 4, 5, 6, 8, 9, 10]].copy()
stationMapData.head()
# Out:
#                 starttime                stoptime start station name  \
# 0 2018-03-01 02:29:13.727 2018-03-01 02:42:50.146   W 52 St & 11 Ave
# 1 2018-03-01 05:12:37.032 2018-03-01 05:16:32.101   W 52 St & 11 Ave
# 2 2018-03-01 05:45:49.900 2018-03-01 06:06:39.908   W 52 St & 11 Ave
# 3 2018-03-01 06:54:19.615 2018-03-01 07:06:40.979   W 52 St & 11 Ave
# 4 2018-03-01 07:08:38.861 2018-03-01 07:20:46.850   W 52 St & 11 Ave
#
#    start station latitude  start station longitude  \
# 0               40.767272               -73.993929
# 1               40.767272               -73.993929
# 2               40.767272               -73.993929
# 3               40.767272               -73.993929
# 4               40.767272               -73.993929
#
#                 end station name  end station latitude  end station longitude
# 0                W 31 St & 7 Ave             40.749156             -73.991600
# 1               11 Ave & W 41 St             40.760301             -73.998842
# ...

# %%
#stationMapData.to_csv('stationMapData.csv', mode = 'w', index=False)

# %%
allCBdata.to_csv('allCBdata.csv', mode = 'w', index=False)

# %%
tripAll = allCBdata.iloc[: , [0, 1, 2, 12, 13, 14, 15]].copy()
tripAll.shape
# Out:
# (5813799, 7)

# %%
#tripAll.to_csv('tripAll.csv', mode = 'w', index=False)

# %%
bikeDataAll = allCBdata.iloc[: , [0, 1, 2, 11]].copy()
bikeDataAll.shape
# Out:
# (5813799, 4)

# %%
#bikeDataAll.to_csv('bikeDataAll.csv', mode = 'w', index=False)

# %%
latLongDataAll = allCBdata.iloc[: , [3, 4, 5, 6, 7, 8, 9, 10]].copy()
latLongDataAll.head()
# Out:
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929           379.0                W 31 St & 7 Ave
# 1               -73.993929           478.0               11 Ave & W 41 St
# 2               -73.993929          3664.0  North Moore St & Greenwich St
# 3               -73.993929           459.0               W 20 St & 11 Ave
# 4               -73.993929          2006.0         Central Park S & 6 Ave
#
#    end station latitude  end station longitude
# 0             40.749156             -73.991600
# ...

# %%
latLongDataAll['start station name'].nunique()
# Out:
# 812

# %%
latLongDataAll['start station id'].nunique()
# Out:
# 811

# %%
latLongDataAll['end station name'].nunique()
# Out:
# 829

# %%
latLongDataAll['end station id'].nunique()
# Out:
# 828

# %%
latLongDataAll['freq'] = latLongDataAll.groupby('start station id')['start station id'].transform('count')
latLongDataAll.head()
# Out:
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929           379.0                W 31 St & 7 Ave
# 1               -73.993929           478.0               11 Ave & W 41 St
# 2               -73.993929          3664.0  North Moore St & Greenwich St
# 3               -73.993929           459.0               W 20 St & 11 Ave
# 4               -73.993929          2006.0         Central Park S & 6 Ave
#
#    end station latitude  end station longitude     freq
# 0             40.749156             -73.991600  12717.0
# ...

# %%
n = 10
latLongDataAll['start station name'].value_counts()[:n].index.tolist()
# Out:
# ['Pershing Square North',
#  'E 17 St & Broadway',
#  'W 21 St & 6 Ave',
#  'Broadway & E 22 St',
#  'West St & Chambers St',
#  'Broadway & E 14 St',
#  '8 Ave & W 33 St',
#  'W 41 St & 8 Ave',
#  'Lafayette St & E 8 St',
#  'Broadway & W 60 St']

# %%
n = 10
latLongDataAll['end station name'].value_counts()[:n].index.tolist()
# Out:
# ['Pershing Square North',
#  'E 17 St & Broadway',
#  'Broadway & E 22 St',
#  'W 21 St & 6 Ave',
#  'West St & Chambers St',
#  'Broadway & E 14 St',
#  '8 Ave & W 33 St',
#  'W 41 St & 8 Ave',
#  'W 20 St & 11 Ave',
#  'Lafayette St & E 8 St']

# %%
#latLongDataAll.to_csv('latLongDataAll.csv', mode = 'w', index=False)
